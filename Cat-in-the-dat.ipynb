# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

# %%
train = pd.read_csv('../data/cat_in_the_dat_train.csv', index_col='id')
test = pd.read_csv('../data/cat_in_the_dat_test.csv', index_col='id')

# %%
train.head()
# Out:
#     bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2    nom_3  \
# id
# 0       0      0      0     T     Y  Green   Triangle    Snake  Finland
# 1       0      1      0     T     Y  Green  Trapezoid  Hamster   Russia
# 2       0      0      0     F     Y   Blue  Trapezoid     Lion   Russia
# 3       0      1      0     F     Y    Red  Trapezoid    Snake   Canada
# 4       0      0      0     F     N    Red  Trapezoid     Lion   Canada
#
#        nom_4  ...      nom_9 ord_0        ord_1        ord_2 ord_3  ord_4  \
# id            ...
# 0    Bassoon  ...  2f4cb3d51     2  Grandmaster         Cold     h      D
# 1      Piano  ...  f83c56c21     1  Grandmaster          Hot     a      A
# 2   Theremin  ...  ae6800dd0     1       Expert     Lava Hot     h      R
# 3       Oboe  ...  8270f0d71     1  Grandmaster  Boiling Hot     i      D
# 4       Oboe  ...  b164b72a7     1  Grandmaster     Freezing     a      R
#
#    ord_5 day month target
# id
# 0     kr   2     2      0
# 1     bF   7     8      0
# 2     Jc   7     2      0
# 3     kW   2     1      1
# 4     qP   7     8      0
#
# [5 rows x 24 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300000 entries, 0 to 299999
# Data columns (total 24 columns):
# bin_0     300000 non-null int64
# bin_1     300000 non-null int64
# bin_2     300000 non-null int64
# bin_3     300000 non-null object
# bin_4     300000 non-null object
# nom_0     300000 non-null object
# nom_1     300000 non-null object
# nom_2     300000 non-null object
# nom_3     300000 non-null object
# nom_4     300000 non-null object
# nom_5     300000 non-null object
# nom_6     300000 non-null object
# nom_7     300000 non-null object
# nom_8     300000 non-null object
# nom_9     300000 non-null object
# ord_0     300000 non-null int64
# ord_1     300000 non-null object
# ord_2     300000 non-null object
# ord_3     300000 non-null object
# ord_4     300000 non-null object
# ord_5     300000 non-null object
# day       300000 non-null int64
# month     300000 non-null int64
# target    300000 non-null int64
# dtypes: int64(7), object(17)
# memory usage: 57.2+ MB

# %%
Y = train['target']
X = train.drop('target', axis=1)

# %%
def fit_result(X, Y,
              n_estimators,
              learning_rate,
              max_depth):
    
    X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3, 
                                                    random_state=17)

    XGB = XGBClassifier(nthread=-1, 
                        n_estimators=n_estimators, 
                        learning_rate=learning_rate, 
                        max_depth=max_depth, 
                        subsample=0.9, 
                        colsample_bytree=0.9)
    
    XGB.fit(X_train, y_train, verbose=200)
    xgb_pred = XGB.predict_proba(X_test)[:, 1]
    return roc_auc_score(y_test, xgb_pred)

# %% [markdown]
# ## Label encoding

# %%
categ_cols = X.select_dtypes(include=['object']).columns.to_list()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
X[categ_cols] = X[categ_cols].apply(lambda x: le.fit_transform(x))
X.head()
# Out:
#     bin_0  bin_1  bin_2  bin_3  bin_4  nom_0  nom_1  nom_2  nom_3  nom_4  ...  \
# id                                                                        ...
# 0       0      0      0      1      1      1      5      5      3      0  ...
# 1       0      1      0      1      1      1      4      3      5      2  ...
# 2       0      0      0      0      1      0      4      4      5      3  ...
# 3       0      1      0      0      1      2      4      5      0      1  ...
# 4       0      0      0      0      0      2      4      4      0      1  ...
#
#     nom_8  nom_9  ord_0  ord_1  ord_2  ord_3  ord_4  ord_5  day  month
# id
# 0    1686   2175      2      2      1      7      3    136    2      2
# 1     650  11635      1      2      3      0      0     93    7      8
# 2    1932   8078      1      1      4      7     17     31    7      2
# 3     629   6056      1      2      0      8      3    134    2      1
# 4    1760   8231      1      2      2      0     17    158    7      8
#
# [5 rows x 23 columns]

# %%
print("tunning learning_rate")
dic = dict()
for l in [0.1, 0.2, 0.3]:
    roc_auc = fit_result(X, Y, 
                 n_estimators=500, 
                 learning_rate=l, 
                 max_depth=3)
    dic[l] = roc_auc
    
dic
# Out:
# tunning learning_rate
# {0.1: 0.7748812042206865, 0.2: 0.7802657459123178, 0.3: 0.7817518415360722}

# %%
print("tunning max_depth")
dic = dict()
for m in [3, 4, 5, 6]:
    roc_auc = fit_result(X, Y, 
                 n_estimators=500, 
                 learning_rate=0.1, 
                 max_depth=m)
    dic[m] = roc_auc
    
dic
# Out:
# tunning max_depth
# {3: 0.7748812042206865,
#  4: 0.7771718693792293,
#  5: 0.7781629894327895,
#  6: 0.7778414586582868}

# %% [markdown]
# ## One hot

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()

# %%
train = pd.read_csv('../data/cat_in_the_dat_train.csv', index_col='id')
test = pd.read_csv('../data/cat_in_the_dat_test.csv', index_col='id')
Y = train['target']
X = train.drop('target', axis=1)

# %%
X = one.fit_transform(X)

# %%
print("tunning learning_rate")
dic = dict()
for l in [0.1, 0.2, 0.3]:
    roc_auc = fit_result(X, Y, 
                 n_estimators=500, 
                 learning_rate=l, 
                 max_depth=3)
    dic[l] = roc_auc
    
dic
# Out:
# tunning learning_rate
# {0.1: 0.7640804840178449, 0.2: 0.774667781780568, 0.3: 0.7782865779450621}

# %%
print("tunning max_depth")
dic = dict()
for m in [7, 9, 11, 13]:
    roc_auc = fit_result(X, Y, 
                 n_estimators=500, 
                 learning_rate=0.1, 
                 max_depth=m)
    dic[m] = roc_auc
    
dic
# Out:
# tunning max_depth
# {7: 0.7724984582977144,
#  9: 0.7721514945772938,
#  11: 0.7712787277817651,
#  13: 0.7694221564511936}

# %% [markdown]
# ## Target encoding

# %%
train = pd.read_csv('../data/cat_in_the_dat_train.csv', index_col='id')
test = pd.read_csv('../data/cat_in_the_dat_test.csv', index_col='id')
train['day']=train['day'].astype('object')
train['month']=train['month'].astype('object')

# %%
categ_cols = train.select_dtypes(include=['object']).columns.to_list()

# %%
for col in categ_cols:
    train[col] = train[col].map(train.groupby(col)['target'].mean())

# %%
train.head()
# Out:
#     bin_0  bin_1  bin_2     bin_3     bin_4     nom_0     nom_1     nom_2  \
# id
# 0       0      0      0  0.302537  0.290107  0.327145  0.360978  0.307162
# 1       0      1      0  0.302537  0.290107  0.327145  0.290054  0.359209
# 2       0      0      0  0.309384  0.290107  0.241790  0.290054  0.293085
# 3       0      1      0  0.309384  0.290107  0.351052  0.290054  0.307162
# 4       0      0      0  0.309384  0.333773  0.351052  0.290054  0.293085
#
#        nom_3     nom_4  ...     nom_9  ord_0     ord_1     ord_2     ord_3  \
# id                      ...
# 0   0.242813  0.237743  ...  0.368421      2  0.403885  0.257877  0.306993
# 1   0.289954  0.304164  ...  0.076923      1  0.403885  0.326315  0.206599
# 2   0.289954  0.353951  ...  0.172414      1  0.317175  0.403126  0.306993
# 3   0.339793  0.329472  ...  0.227273      1  0.403885  0.360961  0.330148
# 4   0.339793  0.329472  ...  0.200000      1  0.403885  0.225214  0.206599
#
#        ord_4     ord_5       day     month  target
# id
# 0   0.208354  0.401186  0.322048  0.244432       0
# 1   0.186877  0.303880  0.340292  0.327496       0
# 2   0.351864  0.206843  0.340292  0.244432       0
# 3   0.208354  0.355985  0.322048  0.255729       1
# 4   0.351864  0.404345  0.340292  0.327496       0
#
# [5 rows x 24 columns]

# %%
Y = train['target']
X = train.drop('target', axis=1)

# %%
print("tunning learning_rate")
dic = dict()
for l in [0.1, 0.2, 0.3]:
    roc_auc = fit_result(X, Y, 
                 n_estimators=500, 
                 learning_rate=l, 
                 max_depth=3)
    dic[l] = roc_auc
    
dic
# Out:
# tunning learning_rate
# {0.1: 0.8309870253690351, 0.2: 0.8294146037197574, 0.3: 0.8269541272511554}

# %% [markdown]
# ## Final

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from hyperopt import hp, tpe, space_eval
from hyperopt.fmin import fmin

# %%
train = pd.read_csv('../data/cat_in_the_dat_train.csv', index_col='id')
test = pd.read_csv('../data/cat_in_the_dat_test.csv', index_col='id')
train['day']=train['day'].astype('object')
train['month']=train['month'].astype('object')

# %%
categ_cols = train.select_dtypes(include=['object']).columns.to_list()
for col in categ_cols:
    train[col] = train[col].map(train.groupby(col)['target'].mean())

# %%
Y = train['target']
X = train.drop('target', axis=1)

# %%
def function(params):
    params = {
        'learning_rate': params['learning_rate'], 
        'max_depth': params['max_depth'], 
        'subsample': params['subsample'], # Доля фичей
        'colsample_bytree': params['colsample_bytree'] # Доля объектов
    }
    
    print("############## RUN ################")
    print("params = {params}".format(params=params))
    
    LGBM = LGBMClassifier(
        n_jobs=-1, 
        n_estimators=500,
        verbose=200,
        **params)
    
    X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3, 
                                                    random_state=17)

       
    LGBM.fit(X_train, y_train)
    pred = LGBM.predict_proba(X_test)[:, 1]
    score = roc_auc_score(y_test, pred)
    print("Score: {score}".format(score=str(score)))
    
    return -score

# %%
lgbm_space =  {
            'learning_rate': hp.quniform('learning_rate', 0.1, 0.5, 0.1),
            'max_depth':  hp.choice('max_depth', np.arange(1, 14, dtype=int)),
            'subsample': hp.quniform('subsample', 0.5, 1, 0.1),
            'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.1)
    }

# %%
best = fmin(fn=function,
            space=lgbm_space,
            # tpe - Tree of Parzen Estimators (TPE)
            algo=tpe.suggest,
            max_evals=50
           )
# Out:
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.9, 'max_depth': 9}
# Score: 0.8076037327952863
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.6000000000000001, 'max_depth': 11}
# Score: 0.8167965095863163
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.2, 'colsample_bytree': 0.7000000000000001, 'max_depth': 5}
# Score: 0.8235787409026047
# ############## RUN ################
# params = {'subsample': 1.0, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.7000000000000001, 'max_depth': 12}
# Score: 0.8159380592881424
# ############## RUN ################
# params = {'subsample': 0.5, 'learning_rate': 0.4, 'colsample_bytree': 0.9, 'max_depth': 1}
# Score: 0.8322244006307595
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.6000000000000001, 'max_depth': 11}
# Score: 0.8095846612545008
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.8, 'max_depth': 4}
# Score: 0.8198804124208231
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.7000000000000001, 'max_depth': 9}
# Score: 0.8088207530954942
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.6000000000000001, 'max_depth': 10}
# Score: 0.808980945654244
# ############## RUN ################
# params = {'subsample': 0.9, 'learning_rate': 0.2, 'colsample_bytree': 1.0, 'max_depth': 8}
# Score: 0.8221634367651913
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.2, 'colsample_bytree': 0.7000000000000001, 'max_depth': 7}
# Score: 0.8233397459795573
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.6000000000000001, 'max_depth': 1}
# Score: 0.8322102469265846
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.8, 'max_depth': 8}
# Score: 0.8101703765803057
# ############## RUN ################
# params = {'subsample': 0.9, 'learning_rate': 0.2, 'colsample_bytree': 0.5, 'max_depth': 13}
# Score: 0.8238887165590649
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.5, 'colsample_bytree': 1.0, 'max_depth': 12}
# Score: 0.7992179031915763
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.2, 'colsample_bytree': 0.7000000000000001, 'max_depth': 3}
# Score: 0.8295027352960658
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.2, 'colsample_bytree': 0.9, 'max_depth': 2}
# Score: 0.831363413666002
# ############## RUN ################
# params = {'subsample': 1.0, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.6000000000000001, 'max_depth': 2}
# Score: 0.8307426076888875
# ############## RUN ################
# params = {'subsample': 0.5, 'learning_rate': 0.4, 'colsample_bytree': 0.6000000000000001, 'max_depth': 5}
# Score: 0.8135824198831171
# ############## RUN ################
# params = {'subsample': 1.0, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 1.0, 'max_depth': 13}
# Score: 0.8148911305348245
# ############## RUN ################
# params = {'subsample': 0.5, 'learning_rate': 0.5, 'colsample_bytree': 0.5, 'max_depth': 1}
# Score: 0.831970778159103
# ############## RUN ################
# params = {'subsample': 0.5, 'learning_rate': 0.5, 'colsample_bytree': 0.9, 'max_depth': 1}
# Score: 0.8321244932935096
# ############## RUN ################
# params = {'subsample': 0.9, 'learning_rate': 0.5, 'colsample_bytree': 0.8, 'max_depth': 1}
# Score: 0.8320550695605808
# ############## RUN ################
# params = {'subsample': 0.5, 'learning_rate': 0.1, 'colsample_bytree': 0.9, 'max_depth': 6}
# Score: 0.8277794683235795
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.5, 'colsample_bytree': 0.8, 'max_depth': 1}
# Score: 0.8320550695605808
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.5, 'max_depth': 1}
# Score: 0.8322105934434959
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.5, 'colsample_bytree': 0.5, 'max_depth': 1}
# Score: 0.831970778159103
# ############## RUN ################
# params = {'subsample': 0.9, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.9, 'max_depth': 6}
# Score: 0.8159469774473742
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.9, 'max_depth': 3}
# Score: 0.8264662610916844
# ############## RUN ################
# params = {'subsample': 0.9, 'learning_rate': 0.5, 'colsample_bytree': 1.0, 'max_depth': 7}
# Score: 0.8006931006840496
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.8, 'max_depth': 4}
# Score: 0.8198804124208231
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 1.0, 'max_depth': 10}
# Score: 0.8145245086658371
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.9, 'max_depth': 9}
# Score: 0.8076037327952863
# ############## RUN ################
# params = {'subsample': 1.0, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.5, 'max_depth': 11}
# Score: 0.8180528740910599
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.7000000000000001, 'max_depth': 1}
# Score: 0.832236298486586
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.1, 'colsample_bytree': 0.7000000000000001, 'max_depth': 5}
# Score: 0.828665364970463
# ############## RUN ################
# params = {'subsample': 0.9, 'learning_rate': 0.5, 'colsample_bytree': 0.8, 'max_depth': 4}
# Score: 0.815920705535176
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.7000000000000001, 'max_depth': 12}
# Score: 0.8159380592881424
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.8, 'max_depth': 11}
# Score: 0.808267779547976
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.7000000000000001, 'max_depth': 9}
# Score: 0.8088207530954942
# ############## RUN ################
# params = {'subsample': 0.5, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.6000000000000001, 'max_depth': 8}
# Score: 0.8175985578617325
# ############## RUN ################
# params = {'subsample': 0.9, 'learning_rate': 0.5, 'colsample_bytree': 0.8, 'max_depth': 10}
# Score: 0.8019322631823267
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.7000000000000001, 'max_depth': 1}
# Score: 0.832236298486586
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.7000000000000001, 'max_depth': 1}
# Score: 0.832236298486586
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.6000000000000001, 'max_depth': 7}
# Score: 0.8116171416625233
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.5, 'colsample_bytree': 0.6000000000000001, 'max_depth': 3}
# Score: 0.8244551693818705
# ############## RUN ################
# params = {'subsample': 0.6000000000000001, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.7000000000000001, 'max_depth': 13}
# Score: 0.8156140398129035
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.4, 'colsample_bytree': 0.7000000000000001, 'max_depth': 12}
# Score: 0.808019374597732
# ############## RUN ################
# params = {'subsample': 0.8, 'learning_rate': 0.4, 'colsample_bytree': 0.6000000000000001, 'max_depth': 2}
# Score: 0.8299545729992308
# ############## RUN ################
# params = {'subsample': 0.7000000000000001, 'learning_rate': 0.30000000000000004, 'colsample_bytree': 0.7000000000000001, 'max_depth': 1}
# Score: 0.8323993027161127
# 100%|██████████| 50/50 [3:56:47<00:00, 191.70s/it, best loss: -0.832399302716]

# %%
best_params = space_eval(lgbm_space, best)
#best_params['max_depth'] = int(best_params['max_depth'])
best_params
# Out:
# {'colsample_bytree': 0.7000000000000001,
#  'learning_rate': 0.30000000000000004,
#  'max_depth': 1,
#  'subsample': 0.7000000000000001}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3, 
                                                    random_state=17)

# %%
LGBM = LGBMClassifier(
        n_jobs=-1, 
        n_estimators=5000,
        verbose=100,
        **best_params
)

LGBM.fit(X_train, 
        y_train,
        eval_metric=['auc'],
        eval_set=[(X_test, y_test)],
        early_stopping_rounds=100)
# Out:
# [1]	valid_0's auc: 0.584435	valid_0's binary_logloss: 0.609584
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 0.635724	valid_0's binary_logloss: 0.601679
# [3]	valid_0's auc: 0.662448	valid_0's binary_logloss: 0.596432
# [4]	valid_0's auc: 0.665231	valid_0's binary_logloss: 0.591652
# [5]	valid_0's auc: 0.684452	valid_0's binary_logloss: 0.58651
# [6]	valid_0's auc: 0.700211	valid_0's binary_logloss: 0.581926
# [7]	valid_0's auc: 0.713198	valid_0's binary_logloss: 0.578573
# [8]	valid_0's auc: 0.709659	valid_0's binary_logloss: 0.575494
# [9]	valid_0's auc: 0.715195	valid_0's binary_logloss: 0.572057
# [10]	valid_0's auc: 0.724778	valid_0's binary_logloss: 0.569048
# [11]	valid_0's auc: 0.733125	valid_0's binary_logloss: 0.566391
# [12]	valid_0's auc: 0.742462	valid_0's binary_logloss: 0.563164
# [13]	valid_0's auc: 0.745042	valid_0's binary_logloss: 0.560469
# [14]	valid_0's auc: 0.747244	valid_0's binary_logloss: 0.557888
# [15]	valid_0's auc: 0.753503	valid_0's binary_logloss: 0.555375
# [16]	valid_0's auc: 0.75599	valid_0's binary_logloss: 0.552844
# [17]	valid_0's auc: 0.75611	valid_0's binary_logloss: 0.55071
# [18]	valid_0's auc: 0.75658	valid_0's binary_logloss: 0.548381
# [19]	valid_0's auc: 0.761307	valid_0's binary_logloss: 0.54637
# [20]	valid_0's auc: 0.766936	valid_0's binary_logloss: 0.543999
# [21]	valid_0's auc: 0.769401	valid_0's binary_logloss: 0.542109
# [22]	valid_0's auc: 0.774089	valid_0's binary_logloss: 0.540066
# [23]	valid_0's auc: 0.777068	valid_0's binary_logloss: 0.53818
# [24]	valid_0's auc: 0.780544	valid_0's binary_logloss: 0.536562
# [25]	valid_0's auc: 0.784012	valid_0's binary_logloss: 0.534922
# [26]	valid_0's auc: 0.783795	valid_0's binary_logloss: 0.533286
# [27]	valid_0's auc: 0.786001	valid_0's binary_logloss: 0.531591
# [28]	valid_0's auc: 0.787724	valid_0's binary_logloss: 0.530164
# [29]	valid_0's auc: 0.788092	valid_0's binary_logloss: 0.528449
# [30]	valid_0's auc: 0.789155	valid_0's binary_logloss: 0.527089
# [31]	valid_0's auc: 0.78921	valid_0's binary_logloss: 0.525632
# [32]	valid_0's auc: 0.791069	valid_0's binary_logloss: 0.524146
# [33]	valid_0's auc: 0.791391	valid_0's binary_logloss: 0.522838
# [34]	valid_0's auc: 0.792956	valid_0's binary_logloss: 0.521579
# [35]	valid_0's auc: 0.792778	valid_0's binary_logloss: 0.520216
# [36]	valid_0's auc: 0.794364	valid_0's binary_logloss: 0.51879
# [37]	valid_0's auc: 0.794341	valid_0's binary_logloss: 0.51755
# [38]	valid_0's auc: 0.795426	valid_0's binary_logloss: 0.516466
# [39]	valid_0's auc: 0.796481	valid_0's binary_logloss: 0.51538
# [40]	valid_0's auc: 0.797645	valid_0's binary_logloss: 0.514149
# [41]	valid_0's auc: 0.798931	valid_0's binary_logloss: 0.513084
# [42]	valid_0's auc: 0.800451	valid_0's binary_logloss: 0.51196
# [43]	valid_0's auc: 0.800883	valid_0's binary_logloss: 0.510838
# [44]	valid_0's auc: 0.802297	valid_0's binary_logloss: 0.509826
# [45]	valid_0's auc: 0.8043	valid_0's binary_logloss: 0.508673
# [46]	valid_0's auc: 0.804614	valid_0's binary_logloss: 0.507677
# [47]	valid_0's auc: 0.8049	valid_0's binary_logloss: 0.506689
# [48]	valid_0's auc: 0.804794	valid_0's binary_logloss: 0.505723
# [49]	valid_0's auc: 0.805439	valid_0's binary_logloss: 0.504857
# [50]	valid_0's auc: 0.806379	valid_0's binary_logloss: 0.503999
# [51]	valid_0's auc: 0.807889	valid_0's binary_logloss: 0.503134
# [52]	valid_0's auc: 0.80918	valid_0's binary_logloss: 0.502332
# [53]	valid_0's auc: 0.809867	valid_0's binary_logloss: 0.501456
# [54]	valid_0's auc: 0.810032	valid_0's binary_logloss: 0.50062
# [55]	valid_0's auc: 0.810113	valid_0's binary_logloss: 0.499859
# [56]	valid_0's auc: 0.810554	valid_0's binary_logloss: 0.499136
# [57]	valid_0's auc: 0.810845	valid_0's binary_logloss: 0.49841
# [58]	valid_0's auc: 0.811042	valid_0's binary_logloss: 0.497781
# [59]	valid_0's auc: 0.812191	valid_0's binary_logloss: 0.49705
# [60]	valid_0's auc: 0.812548	valid_0's binary_logloss: 0.496493
# [61]	valid_0's auc: 0.812528	valid_0's binary_logloss: 0.495891
# [62]	valid_0's auc: 0.812879	valid_0's binary_logloss: 0.495244
# [63]	valid_0's auc: 0.812915	valid_0's binary_logloss: 0.494517
# [64]	valid_0's auc: 0.813465	valid_0's binary_logloss: 0.493804
# [65]	valid_0's auc: 0.81331	valid_0's binary_logloss: 0.493212
# [66]	valid_0's auc: 0.813818	valid_0's binary_logloss: 0.492498
# [67]	valid_0's auc: 0.814485	valid_0's binary_logloss: 0.491887
# [68]	valid_0's auc: 0.815184	valid_0's binary_logloss: 0.491228
# [69]	valid_0's auc: 0.815661	valid_0's binary_logloss: 0.490595
# [70]	valid_0's auc: 0.816092	valid_0's binary_logloss: 0.490006
# [71]	valid_0's auc: 0.815978	valid_0's binary_logloss: 0.489398
# [72]	valid_0's auc: 0.816585	valid_0's binary_logloss: 0.488914
# [73]	valid_0's auc: 0.817283	valid_0's binary_logloss: 0.488391
# [74]	valid_0's auc: 0.817737	valid_0's binary_logloss: 0.487803
# [75]	valid_0's auc: 0.818484	valid_0's binary_logloss: 0.487263
# [76]	valid_0's auc: 0.818638	valid_0's binary_logloss: 0.486833
# [77]	valid_0's auc: 0.819324	valid_0's binary_logloss: 0.486276
# [78]	valid_0's auc: 0.820063	valid_0's binary_logloss: 0.485646
# [79]	valid_0's auc: 0.820619	valid_0's binary_logloss: 0.485204
# [80]	valid_0's auc: 0.820953	valid_0's binary_logloss: 0.484577
# [81]	valid_0's auc: 0.820778	valid_0's binary_logloss: 0.48408
# [82]	valid_0's auc: 0.820374	valid_0's binary_logloss: 0.483566
# [83]	valid_0's auc: 0.820434	valid_0's binary_logloss: 0.483036
# [84]	valid_0's auc: 0.820682	valid_0's binary_logloss: 0.48258
# [85]	valid_0's auc: 0.821127	valid_0's binary_logloss: 0.482061
# [86]	valid_0's auc: 0.821615	valid_0's binary_logloss: 0.481651
# [87]	valid_0's auc: 0.821949	valid_0's binary_logloss: 0.481119
# [88]	valid_0's auc: 0.822143	valid_0's binary_logloss: 0.480702
# [89]	valid_0's auc: 0.822314	valid_0's binary_logloss: 0.480227
# [90]	valid_0's auc: 0.822499	valid_0's binary_logloss: 0.479872
# [91]	valid_0's auc: 0.822503	valid_0's binary_logloss: 0.479548
# [92]	valid_0's auc: 0.822862	valid_0's binary_logloss: 0.479203
# [93]	valid_0's auc: 0.823045	valid_0's binary_logloss: 0.47884
# [94]	valid_0's auc: 0.82311	valid_0's binary_logloss: 0.478557
# [95]	valid_0's auc: 0.823322	valid_0's binary_logloss: 0.478144
# [96]	valid_0's auc: 0.82318	valid_0's binary_logloss: 0.477707
# [97]	valid_0's auc: 0.823112	valid_0's binary_logloss: 0.477345
# [98]	valid_0's auc: 0.823271	valid_0's binary_logloss: 0.476992
# [99]	valid_0's auc: 0.823417	valid_0's binary_logloss: 0.476665
# [100]	valid_0's auc: 0.823534	valid_0's binary_logloss: 0.47629
# [101]	valid_0's auc: 0.82377	valid_0's binary_logloss: 0.475907
# [102]	valid_0's auc: 0.823939	valid_0's binary_logloss: 0.475573
# [103]	valid_0's auc: 0.823876	valid_0's binary_logloss: 0.475215
# [104]	valid_0's auc: 0.824028	valid_0's binary_logloss: 0.474859
# [105]	valid_0's auc: 0.823722	valid_0's binary_logloss: 0.474563
# [106]	valid_0's auc: 0.823815	valid_0's binary_logloss: 0.474324
# [107]	valid_0's auc: 0.823742	valid_0's binary_logloss: 0.474008
# [108]	valid_0's auc: 0.823749	valid_0's binary_logloss: 0.473706
# [109]	valid_0's auc: 0.824084	valid_0's binary_logloss: 0.473344
# [110]	valid_0's auc: 0.824109	valid_0's binary_logloss: 0.473033
# [111]	valid_0's auc: 0.824104	valid_0's binary_logloss: 0.472792
# [112]	valid_0's auc: 0.8241	valid_0's binary_logloss: 0.472532
# [113]	valid_0's auc: 0.824278	valid_0's binary_logloss: 0.472249
# [114]	valid_0's auc: 0.824557	valid_0's binary_logloss: 0.47197
# [115]	valid_0's auc: 0.824783	valid_0's binary_logloss: 0.471649
# [116]	valid_0's auc: 0.82494	valid_0's binary_logloss: 0.471441
# [117]	valid_0's auc: 0.825167	valid_0's binary_logloss: 0.471203
# [118]	valid_0's auc: 0.825417	valid_0's binary_logloss: 0.470937
# [119]	valid_0's auc: 0.825611	valid_0's binary_logloss: 0.470665
# [120]	valid_0's auc: 0.825759	valid_0's binary_logloss: 0.470429
# [121]	valid_0's auc: 0.825917	valid_0's binary_logloss: 0.47012
# [122]	valid_0's auc: 0.82596	valid_0's binary_logloss: 0.469887
# [123]	valid_0's auc: 0.826171	valid_0's binary_logloss: 0.469641
# [124]	valid_0's auc: 0.826405	valid_0's binary_logloss: 0.469384
# [125]	valid_0's auc: 0.826469	valid_0's binary_logloss: 0.469138
# [126]	valid_0's auc: 0.826633	valid_0's binary_logloss: 0.468886
# [127]	valid_0's auc: 0.826799	valid_0's binary_logloss: 0.46869
# [128]	valid_0's auc: 0.82694	valid_0's binary_logloss: 0.468511
# [129]	valid_0's auc: 0.826816	valid_0's binary_logloss: 0.468308
# [130]	valid_0's auc: 0.826857	valid_0's binary_logloss: 0.468161
# [131]	valid_0's auc: 0.826862	valid_0's binary_logloss: 0.46799
# [132]	valid_0's auc: 0.826962	valid_0's binary_logloss: 0.467738
# [133]	valid_0's auc: 0.827074	valid_0's binary_logloss: 0.467543
# [134]	valid_0's auc: 0.827237	valid_0's binary_logloss: 0.467356
# [135]	valid_0's auc: 0.827252	valid_0's binary_logloss: 0.467132
# [136]	valid_0's auc: 0.827329	valid_0's binary_logloss: 0.466935
# [137]	valid_0's auc: 0.827406	valid_0's binary_logloss: 0.466765
# [138]	valid_0's auc: 0.827487	valid_0's binary_logloss: 0.466569
# [139]	valid_0's auc: 0.827597	valid_0's binary_logloss: 0.466365
# [140]	valid_0's auc: 0.827648	valid_0's binary_logloss: 0.466211
# [141]	valid_0's auc: 0.827708	valid_0's binary_logloss: 0.465987
# [142]	valid_0's auc: 0.827654	valid_0's binary_logloss: 0.4658
# [143]	valid_0's auc: 0.827906	valid_0's binary_logloss: 0.465558
# [144]	valid_0's auc: 0.828075	valid_0's binary_logloss: 0.465376
# [145]	valid_0's auc: 0.828185	valid_0's binary_logloss: 0.465153
# [146]	valid_0's auc: 0.828287	valid_0's binary_logloss: 0.465002
# [147]	valid_0's auc: 0.828147	valid_0's binary_logloss: 0.464827
# [148]	valid_0's auc: 0.828203	valid_0's binary_logloss: 0.464648
# [149]	valid_0's auc: 0.828191	valid_0's binary_logloss: 0.464548
# [150]	valid_0's auc: 0.828319	valid_0's binary_logloss: 0.464374
# [151]	valid_0's auc: 0.828317	valid_0's binary_logloss: 0.464179
# [152]	valid_0's auc: 0.828396	valid_0's binary_logloss: 0.46407
# [153]	valid_0's auc: 0.828535	valid_0's binary_logloss: 0.463859
# [154]	valid_0's auc: 0.828556	valid_0's binary_logloss: 0.463757
# [155]	valid_0's auc: 0.828669	valid_0's binary_logloss: 0.463613
# [156]	valid_0's auc: 0.828804	valid_0's binary_logloss: 0.463445
# [157]	valid_0's auc: 0.828893	valid_0's binary_logloss: 0.463294
# [158]	valid_0's auc: 0.829056	valid_0's binary_logloss: 0.463131
# [159]	valid_0's auc: 0.829149	valid_0's binary_logloss: 0.46295
# [160]	valid_0's auc: 0.829226	valid_0's binary_logloss: 0.46278
# [161]	valid_0's auc: 0.829253	valid_0's binary_logloss: 0.462643
# [162]	valid_0's auc: 0.829172	valid_0's binary_logloss: 0.46252
# [163]	valid_0's auc: 0.829187	valid_0's binary_logloss: 0.462405
# [164]	valid_0's auc: 0.829272	valid_0's binary_logloss: 0.462276
# [165]	valid_0's auc: 0.829346	valid_0's binary_logloss: 0.46217
# [166]	valid_0's auc: 0.829429	valid_0's binary_logloss: 0.462025
# [167]	valid_0's auc: 0.829433	valid_0's binary_logloss: 0.461874
# [168]	valid_0's auc: 0.829439	valid_0's binary_logloss: 0.461737
# [169]	valid_0's auc: 0.829411	valid_0's binary_logloss: 0.461606
# [170]	valid_0's auc: 0.829379	valid_0's binary_logloss: 0.461507
# [171]	valid_0's auc: 0.82943	valid_0's binary_logloss: 0.461387
# [172]	valid_0's auc: 0.8295	valid_0's binary_logloss: 0.461248
# [173]	valid_0's auc: 0.82954	valid_0's binary_logloss: 0.461132
# [174]	valid_0's auc: 0.829512	valid_0's binary_logloss: 0.461039
# [175]	valid_0's auc: 0.829621	valid_0's binary_logloss: 0.460868
# [176]	valid_0's auc: 0.829679	valid_0's binary_logloss: 0.46073
# [177]	valid_0's auc: 0.82979	valid_0's binary_logloss: 0.460622
# [178]	valid_0's auc: 0.829776	valid_0's binary_logloss: 0.460548
# [179]	valid_0's auc: 0.829791	valid_0's binary_logloss: 0.460483
# [180]	valid_0's auc: 0.829842	valid_0's binary_logloss: 0.460395
# [181]	valid_0's auc: 0.829848	valid_0's binary_logloss: 0.46029
# [182]	valid_0's auc: 0.829841	valid_0's binary_logloss: 0.46024
# [183]	valid_0's auc: 0.829842	valid_0's binary_logloss: 0.460093
# [184]	valid_0's auc: 0.829911	valid_0's binary_logloss: 0.459997
# [185]	valid_0's auc: 0.82988	valid_0's binary_logloss: 0.459904
# [186]	valid_0's auc: 0.829899	valid_0's binary_logloss: 0.459784
# [187]	valid_0's auc: 0.829956	valid_0's binary_logloss: 0.459709
# [188]	valid_0's auc: 0.829992	valid_0's binary_logloss: 0.459616
# [189]	valid_0's auc: 0.830013	valid_0's binary_logloss: 0.459547
# [190]	valid_0's auc: 0.830089	valid_0's binary_logloss: 0.459432
# [191]	valid_0's auc: 0.830133	valid_0's binary_logloss: 0.459342
# [192]	valid_0's auc: 0.830182	valid_0's binary_logloss: 0.459242
# [193]	valid_0's auc: 0.830234	valid_0's binary_logloss: 0.459155
# [194]	valid_0's auc: 0.83031	valid_0's binary_logloss: 0.459059
# [195]	valid_0's auc: 0.830342	valid_0's binary_logloss: 0.458943
# [196]	valid_0's auc: 0.830438	valid_0's binary_logloss: 0.458814
# [197]	valid_0's auc: 0.830465	valid_0's binary_logloss: 0.458749
# [198]	valid_0's auc: 0.830423	valid_0's binary_logloss: 0.458667
# [199]	valid_0's auc: 0.830476	valid_0's binary_logloss: 0.458558
# [200]	valid_0's auc: 0.83047	valid_0's binary_logloss: 0.458493
# [201]	valid_0's auc: 0.83052	valid_0's binary_logloss: 0.458416
# [202]	valid_0's auc: 0.830517	valid_0's binary_logloss: 0.458351
# [203]	valid_0's auc: 0.830568	valid_0's binary_logloss: 0.458275
# [204]	valid_0's auc: 0.830606	valid_0's binary_logloss: 0.458185
# [205]	valid_0's auc: 0.83058	valid_0's binary_logloss: 0.458141
# [206]	valid_0's auc: 0.830551	valid_0's binary_logloss: 0.458114
# [207]	valid_0's auc: 0.830622	valid_0's binary_logloss: 0.458018
# [208]	valid_0's auc: 0.830623	valid_0's binary_logloss: 0.457936
# [209]	valid_0's auc: 0.830647	valid_0's binary_logloss: 0.457849
# [210]	valid_0's auc: 0.830667	valid_0's binary_logloss: 0.457778
# [211]	valid_0's auc: 0.830608	valid_0's binary_logloss: 0.457719
# [212]	valid_0's auc: 0.830582	valid_0's binary_logloss: 0.457679
# [213]	valid_0's auc: 0.830641	valid_0's binary_logloss: 0.457604
# [214]	valid_0's auc: 0.830669	valid_0's binary_logloss: 0.457559
# [215]	valid_0's auc: 0.830728	valid_0's binary_logloss: 0.457486
# [216]	valid_0's auc: 0.830709	valid_0's binary_logloss: 0.457409
# [217]	valid_0's auc: 0.830748	valid_0's binary_logloss: 0.457335
# [218]	valid_0's auc: 0.83079	valid_0's binary_logloss: 0.457246
# [219]	valid_0's auc: 0.830815	valid_0's binary_logloss: 0.457197
# [220]	valid_0's auc: 0.830906	valid_0's binary_logloss: 0.457098
# [221]	valid_0's auc: 0.830937	valid_0's binary_logloss: 0.457025
# [222]	valid_0's auc: 0.830978	valid_0's binary_logloss: 0.45695
# [223]	valid_0's auc: 0.830986	valid_0's binary_logloss: 0.456884
# [224]	valid_0's auc: 0.830994	valid_0's binary_logloss: 0.45681
# [225]	valid_0's auc: 0.83103	valid_0's binary_logloss: 0.456731
# [226]	valid_0's auc: 0.831043	valid_0's binary_logloss: 0.45669
# [227]	valid_0's auc: 0.831007	valid_0's binary_logloss: 0.456663
# [228]	valid_0's auc: 0.831041	valid_0's binary_logloss: 0.456586
# [229]	valid_0's auc: 0.831098	valid_0's binary_logloss: 0.456491
# [230]	valid_0's auc: 0.831115	valid_0's binary_logloss: 0.456438
# [231]	valid_0's auc: 0.831154	valid_0's binary_logloss: 0.456385
# [232]	valid_0's auc: 0.831145	valid_0's binary_logloss: 0.456346
# [233]	valid_0's auc: 0.831117	valid_0's binary_logloss: 0.456294
# [234]	valid_0's auc: 0.831115	valid_0's binary_logloss: 0.456226
# [235]	valid_0's auc: 0.831134	valid_0's binary_logloss: 0.456173
# [236]	valid_0's auc: 0.831154	valid_0's binary_logloss: 0.456115
# [237]	valid_0's auc: 0.831193	valid_0's binary_logloss: 0.456056
# [238]	valid_0's auc: 0.831236	valid_0's binary_logloss: 0.455992
# [239]	valid_0's auc: 0.831278	valid_0's binary_logloss: 0.455931
# [240]	valid_0's auc: 0.831267	valid_0's binary_logloss: 0.45591
# [241]	valid_0's auc: 0.831249	valid_0's binary_logloss: 0.455866
# [242]	valid_0's auc: 0.831287	valid_0's binary_logloss: 0.455791
# [243]	valid_0's auc: 0.831258	valid_0's binary_logloss: 0.455747
# [244]	valid_0's auc: 0.831282	valid_0's binary_logloss: 0.455687
# [245]	valid_0's auc: 0.831299	valid_0's binary_logloss: 0.455654
# [246]	valid_0's auc: 0.831308	valid_0's binary_logloss: 0.455615
# [247]	valid_0's auc: 0.8313	valid_0's binary_logloss: 0.455571
# [248]	valid_0's auc: 0.831323	valid_0's binary_logloss: 0.455529
# [249]	valid_0's auc: 0.831341	valid_0's binary_logloss: 0.455478
# [250]	valid_0's auc: 0.831359	valid_0's binary_logloss: 0.45545
# [251]	valid_0's auc: 0.831363	valid_0's binary_logloss: 0.455429
# [252]	valid_0's auc: 0.831375	valid_0's binary_logloss: 0.455384
# [253]	valid_0's auc: 0.831422	valid_0's binary_logloss: 0.455329
# [254]	valid_0's auc: 0.831442	valid_0's binary_logloss: 0.455302
# [255]	valid_0's auc: 0.831429	valid_0's binary_logloss: 0.455289
# [256]	valid_0's auc: 0.831406	valid_0's binary_logloss: 0.45527
# [257]	valid_0's auc: 0.831432	valid_0's binary_logloss: 0.45523
# [258]	valid_0's auc: 0.831447	valid_0's binary_logloss: 0.455173
# [259]	valid_0's auc: 0.831429	valid_0's binary_logloss: 0.455154
# [260]	valid_0's auc: 0.831467	valid_0's binary_logloss: 0.455101
# [261]	valid_0's auc: 0.831473	valid_0's binary_logloss: 0.455061
# [262]	valid_0's auc: 0.831469	valid_0's binary_logloss: 0.455042
# [263]	valid_0's auc: 0.831487	valid_0's binary_logloss: 0.455009
# [264]	valid_0's auc: 0.831494	valid_0's binary_logloss: 0.454957
# [265]	valid_0's auc: 0.831528	valid_0's binary_logloss: 0.454899
# [266]	valid_0's auc: 0.831503	valid_0's binary_logloss: 0.454897
# [267]	valid_0's auc: 0.831509	valid_0's binary_logloss: 0.454842
# [268]	valid_0's auc: 0.831534	valid_0's binary_logloss: 0.454789
# [269]	valid_0's auc: 0.831515	valid_0's binary_logloss: 0.45475
# [270]	valid_0's auc: 0.831519	valid_0's binary_logloss: 0.454705
# [271]	valid_0's auc: 0.831563	valid_0's binary_logloss: 0.454658
# [272]	valid_0's auc: 0.831585	valid_0's binary_logloss: 0.454617
# [273]	valid_0's auc: 0.831615	valid_0's binary_logloss: 0.454583
# [274]	valid_0's auc: 0.831596	valid_0's binary_logloss: 0.454579
# [275]	valid_0's auc: 0.831605	valid_0's binary_logloss: 0.454544
# [276]	valid_0's auc: 0.831595	valid_0's binary_logloss: 0.454522
# [277]	valid_0's auc: 0.831606	valid_0's binary_logloss: 0.454484
# [278]	valid_0's auc: 0.831604	valid_0's binary_logloss: 0.454464
# [279]	valid_0's auc: 0.831658	valid_0's binary_logloss: 0.454402
# [280]	valid_0's auc: 0.83167	valid_0's binary_logloss: 0.454361
# [281]	valid_0's auc: 0.831673	valid_0's binary_logloss: 0.454323
# [282]	valid_0's auc: 0.831696	valid_0's binary_logloss: 0.454276
# [283]	valid_0's auc: 0.831717	valid_0's binary_logloss: 0.454248
# [284]	valid_0's auc: 0.831728	valid_0's binary_logloss: 0.454219
# [285]	valid_0's auc: 0.831753	valid_0's binary_logloss: 0.454181
# [286]	valid_0's auc: 0.831751	valid_0's binary_logloss: 0.454174
# [287]	valid_0's auc: 0.831771	valid_0's binary_logloss: 0.454154
# [288]	valid_0's auc: 0.831766	valid_0's binary_logloss: 0.454144
# [289]	valid_0's auc: 0.831773	valid_0's binary_logloss: 0.454132
# [290]	valid_0's auc: 0.83178	valid_0's binary_logloss: 0.454104
# [291]	valid_0's auc: 0.831764	valid_0's binary_logloss: 0.45408
# [292]	valid_0's auc: 0.831758	valid_0's binary_logloss: 0.454062
# [293]	valid_0's auc: 0.831747	valid_0's binary_logloss: 0.454039
# [294]	valid_0's auc: 0.831754	valid_0's binary_logloss: 0.454015
# [295]	valid_0's auc: 0.831787	valid_0's binary_logloss: 0.453972
# [296]	valid_0's auc: 0.831797	valid_0's binary_logloss: 0.45395
# [297]	valid_0's auc: 0.831788	valid_0's binary_logloss: 0.45392
# [298]	valid_0's auc: 0.831793	valid_0's binary_logloss: 0.453905
# [299]	valid_0's auc: 0.831792	valid_0's binary_logloss: 0.453879
# [300]	valid_0's auc: 0.831787	valid_0's binary_logloss: 0.453861
# [301]	valid_0's auc: 0.831806	valid_0's binary_logloss: 0.45383
# [302]	valid_0's auc: 0.831811	valid_0's binary_logloss: 0.453808
# [303]	valid_0's auc: 0.831831	valid_0's binary_logloss: 0.453782
# [304]	valid_0's auc: 0.831845	valid_0's binary_logloss: 0.453738
# [305]	valid_0's auc: 0.831856	valid_0's binary_logloss: 0.453702
# [306]	valid_0's auc: 0.831877	valid_0's binary_logloss: 0.453669
# [307]	valid_0's auc: 0.83188	valid_0's binary_logloss: 0.453655
# [308]	valid_0's auc: 0.831865	valid_0's binary_logloss: 0.453653
# [309]	valid_0's auc: 0.831865	valid_0's binary_logloss: 0.453649
# [310]	valid_0's auc: 0.831882	valid_0's binary_logloss: 0.45363
# [311]	valid_0's auc: 0.831889	valid_0's binary_logloss: 0.453602
# [312]	valid_0's auc: 0.831907	valid_0's binary_logloss: 0.453572
# [313]	valid_0's auc: 0.83189	valid_0's binary_logloss: 0.453571
# [314]	valid_0's auc: 0.831885	valid_0's binary_logloss: 0.45356
# [315]	valid_0's auc: 0.83188	valid_0's binary_logloss: 0.453556
# [316]	valid_0's auc: 0.831888	valid_0's binary_logloss: 0.45354
# [317]	valid_0's auc: 0.831913	valid_0's binary_logloss: 0.453499
# [318]	valid_0's auc: 0.831941	valid_0's binary_logloss: 0.453457
# [319]	valid_0's auc: 0.831927	valid_0's binary_logloss: 0.453457
# [320]	valid_0's auc: 0.831936	valid_0's binary_logloss: 0.453433
# [321]	valid_0's auc: 0.831951	valid_0's binary_logloss: 0.453402
# [322]	valid_0's auc: 0.831957	valid_0's binary_logloss: 0.453371
# [323]	valid_0's auc: 0.831971	valid_0's binary_logloss: 0.453343
# [324]	valid_0's auc: 0.831965	valid_0's binary_logloss: 0.453325
# [325]	valid_0's auc: 0.831982	valid_0's binary_logloss: 0.453301
# [326]	valid_0's auc: 0.832002	valid_0's binary_logloss: 0.453268
# [327]	valid_0's auc: 0.831992	valid_0's binary_logloss: 0.453259
# [328]	valid_0's auc: 0.831973	valid_0's binary_logloss: 0.453266
# [329]	valid_0's auc: 0.831993	valid_0's binary_logloss: 0.453239
# [330]	valid_0's auc: 0.831991	valid_0's binary_logloss: 0.45322
# [331]	valid_0's auc: 0.831984	valid_0's binary_logloss: 0.453215
# [332]	valid_0's auc: 0.832005	valid_0's binary_logloss: 0.453189
# [333]	valid_0's auc: 0.832002	valid_0's binary_logloss: 0.453182
# [334]	valid_0's auc: 0.832007	valid_0's binary_logloss: 0.453164
# [335]	valid_0's auc: 0.832008	valid_0's binary_logloss: 0.453152
# [336]	valid_0's auc: 0.832009	valid_0's binary_logloss: 0.453143
# [337]	valid_0's auc: 0.832034	valid_0's binary_logloss: 0.453114
# [338]	valid_0's auc: 0.83204	valid_0's binary_logloss: 0.453101
# [339]	valid_0's auc: 0.832029	valid_0's binary_logloss: 0.453097
# [340]	valid_0's auc: 0.832052	valid_0's binary_logloss: 0.453066
# [341]	valid_0's auc: 0.832048	valid_0's binary_logloss: 0.453059
# [342]	valid_0's auc: 0.832041	valid_0's binary_logloss: 0.453048
# [343]	valid_0's auc: 0.832052	valid_0's binary_logloss: 0.453031
# [344]	valid_0's auc: 0.832054	valid_0's binary_logloss: 0.453017
# [345]	valid_0's auc: 0.832047	valid_0's binary_logloss: 0.453013
# [346]	valid_0's auc: 0.832069	valid_0's binary_logloss: 0.452977
# [347]	valid_0's auc: 0.832063	valid_0's binary_logloss: 0.452962
# [348]	valid_0's auc: 0.832058	valid_0's binary_logloss: 0.452945
# [349]	valid_0's auc: 0.832058	valid_0's binary_logloss: 0.452929
# [350]	valid_0's auc: 0.83206	valid_0's binary_logloss: 0.452917
# [351]	valid_0's auc: 0.832062	valid_0's binary_logloss: 0.452904
# [352]	valid_0's auc: 0.832073	valid_0's binary_logloss: 0.452888
# [353]	valid_0's auc: 0.832086	valid_0's binary_logloss: 0.452867
# [354]	valid_0's auc: 0.832089	valid_0's binary_logloss: 0.45285
# [355]	valid_0's auc: 0.832103	valid_0's binary_logloss: 0.452833
# [356]	valid_0's auc: 0.832101	valid_0's binary_logloss: 0.452825
# [357]	valid_0's auc: 0.832109	valid_0's binary_logloss: 0.452806
# [358]	valid_0's auc: 0.832118	valid_0's binary_logloss: 0.452786
# [359]	valid_0's auc: 0.832132	valid_0's binary_logloss: 0.452769
# [360]	valid_0's auc: 0.832149	valid_0's binary_logloss: 0.452742
# [361]	valid_0's auc: 0.832174	valid_0's binary_logloss: 0.452714
# [362]	valid_0's auc: 0.832174	valid_0's binary_logloss: 0.45271
# [363]	valid_0's auc: 0.832176	valid_0's binary_logloss: 0.4527
# [364]	valid_0's auc: 0.832179	valid_0's binary_logloss: 0.452684
# [365]	valid_0's auc: 0.832175	valid_0's binary_logloss: 0.452672
# [366]	valid_0's auc: 0.832169	valid_0's binary_logloss: 0.452675
# [367]	valid_0's auc: 0.832158	valid_0's binary_logloss: 0.452674
# [368]	valid_0's auc: 0.832164	valid_0's binary_logloss: 0.452657
# [369]	valid_0's auc: 0.832161	valid_0's binary_logloss: 0.452653
# [370]	valid_0's auc: 0.832155	valid_0's binary_logloss: 0.452643
# [371]	valid_0's auc: 0.832162	valid_0's binary_logloss: 0.452626
# [372]	valid_0's auc: 0.832158	valid_0's binary_logloss: 0.452629
# [373]	valid_0's auc: 0.832167	valid_0's binary_logloss: 0.452613
# [374]	valid_0's auc: 0.83218	valid_0's binary_logloss: 0.452594
# [375]	valid_0's auc: 0.832194	valid_0's binary_logloss: 0.452572
# [376]	valid_0's auc: 0.832189	valid_0's binary_logloss: 0.452564
# [377]	valid_0's auc: 0.832194	valid_0's binary_logloss: 0.452547
# [378]	valid_0's auc: 0.832204	valid_0's binary_logloss: 0.452527
# [379]	valid_0's auc: 0.832208	valid_0's binary_logloss: 0.452515
# [380]	valid_0's auc: 0.832195	valid_0's binary_logloss: 0.452519
# [381]	valid_0's auc: 0.832193	valid_0's binary_logloss: 0.452514
# [382]	valid_0's auc: 0.832203	valid_0's binary_logloss: 0.452504
# [383]	valid_0's auc: 0.832217	valid_0's binary_logloss: 0.452492
# [384]	valid_0's auc: 0.832219	valid_0's binary_logloss: 0.45248
# [385]	valid_0's auc: 0.832224	valid_0's binary_logloss: 0.45247
# [386]	valid_0's auc: 0.832225	valid_0's binary_logloss: 0.452459
# [387]	valid_0's auc: 0.832227	valid_0's binary_logloss: 0.452455
# [388]	valid_0's auc: 0.832226	valid_0's binary_logloss: 0.452452
# [389]	valid_0's auc: 0.832221	valid_0's binary_logloss: 0.452451
# [390]	valid_0's auc: 0.832236	valid_0's binary_logloss: 0.452432
# [391]	valid_0's auc: 0.832225	valid_0's binary_logloss: 0.452437
# [392]	valid_0's auc: 0.83221	valid_0's binary_logloss: 0.452446
# [393]	valid_0's auc: 0.832204	valid_0's binary_logloss: 0.452444
# [394]	valid_0's auc: 0.832209	valid_0's binary_logloss: 0.452426
# [395]	valid_0's auc: 0.832226	valid_0's binary_logloss: 0.452402
# [396]	valid_0's auc: 0.832221	valid_0's binary_logloss: 0.452396
# [397]	valid_0's auc: 0.832209	valid_0's binary_logloss: 0.452397
# [398]	valid_0's auc: 0.832217	valid_0's binary_logloss: 0.452385
# [399]	valid_0's auc: 0.832223	valid_0's binary_logloss: 0.452368
# [400]	valid_0's auc: 0.832223	valid_0's binary_logloss: 0.452361
# [401]	valid_0's auc: 0.832226	valid_0's binary_logloss: 0.452355
# [402]	valid_0's auc: 0.832236	valid_0's binary_logloss: 0.45234
# [403]	valid_0's auc: 0.832237	valid_0's binary_logloss: 0.452334
# [404]	valid_0's auc: 0.832246	valid_0's binary_logloss: 0.452318
# [405]	valid_0's auc: 0.832256	valid_0's binary_logloss: 0.452308
# [406]	valid_0's auc: 0.832264	valid_0's binary_logloss: 0.452299
# [407]	valid_0's auc: 0.832259	valid_0's binary_logloss: 0.452294
# [408]	valid_0's auc: 0.832273	valid_0's binary_logloss: 0.45227
# [409]	valid_0's auc: 0.832278	valid_0's binary_logloss: 0.452261
# [410]	valid_0's auc: 0.832283	valid_0's binary_logloss: 0.452252
# [411]	valid_0's auc: 0.832284	valid_0's binary_logloss: 0.452247
# [412]	valid_0's auc: 0.832278	valid_0's binary_logloss: 0.452248
# [413]	valid_0's auc: 0.832278	valid_0's binary_logloss: 0.452244
# [414]	valid_0's auc: 0.832274	valid_0's binary_logloss: 0.452242
# [415]	valid_0's auc: 0.832275	valid_0's binary_logloss: 0.452233
# [416]	valid_0's auc: 0.832288	valid_0's binary_logloss: 0.452219
# [417]	valid_0's auc: 0.832276	valid_0's binary_logloss: 0.452224
# [418]	valid_0's auc: 0.832284	valid_0's binary_logloss: 0.45221
# [419]	valid_0's auc: 0.832286	valid_0's binary_logloss: 0.452203
# [420]	valid_0's auc: 0.832288	valid_0's binary_logloss: 0.452201
# [421]	valid_0's auc: 0.832281	valid_0's binary_logloss: 0.452204
# [422]	valid_0's auc: 0.832288	valid_0's binary_logloss: 0.452192
# [423]	valid_0's auc: 0.832281	valid_0's binary_logloss: 0.452194
# [424]	valid_0's auc: 0.83229	valid_0's binary_logloss: 0.452183
# [425]	valid_0's auc: 0.83229	valid_0's binary_logloss: 0.452176
# [426]	valid_0's auc: 0.832289	valid_0's binary_logloss: 0.452167
# [427]	valid_0's auc: 0.832288	valid_0's binary_logloss: 0.452161
# [428]	valid_0's auc: 0.832293	valid_0's binary_logloss: 0.452153
# [429]	valid_0's auc: 0.832298	valid_0's binary_logloss: 0.452143
# [430]	valid_0's auc: 0.8323	valid_0's binary_logloss: 0.452138
# [431]	valid_0's auc: 0.832316	valid_0's binary_logloss: 0.452121
# [432]	valid_0's auc: 0.832318	valid_0's binary_logloss: 0.452117
# [433]	valid_0's auc: 0.832316	valid_0's binary_logloss: 0.452115
# [434]	valid_0's auc: 0.832317	valid_0's binary_logloss: 0.45211
# [435]	valid_0's auc: 0.83231	valid_0's binary_logloss: 0.452115
# [436]	valid_0's auc: 0.832315	valid_0's binary_logloss: 0.452105
# [437]	valid_0's auc: 0.832318	valid_0's binary_logloss: 0.452102
# [438]	valid_0's auc: 0.832313	valid_0's binary_logloss: 0.452099
# [439]	valid_0's auc: 0.832317	valid_0's binary_logloss: 0.452092
# [440]	valid_0's auc: 0.832328	valid_0's binary_logloss: 0.452077
# [441]	valid_0's auc: 0.832331	valid_0's binary_logloss: 0.452072
# [442]	valid_0's auc: 0.83233	valid_0's binary_logloss: 0.452074
# [443]	valid_0's auc: 0.832332	valid_0's binary_logloss: 0.45207
# [444]	valid_0's auc: 0.832339	valid_0's binary_logloss: 0.452061
# [445]	valid_0's auc: 0.83234	valid_0's binary_logloss: 0.452054
# [446]	valid_0's auc: 0.832347	valid_0's binary_logloss: 0.452043
# [447]	valid_0's auc: 0.832346	valid_0's binary_logloss: 0.452038
# [448]	valid_0's auc: 0.832344	valid_0's binary_logloss: 0.452037
# [449]	valid_0's auc: 0.832344	valid_0's binary_logloss: 0.452031
# [450]	valid_0's auc: 0.832349	valid_0's binary_logloss: 0.452025
# [451]	valid_0's auc: 0.832348	valid_0's binary_logloss: 0.452025
# [452]	valid_0's auc: 0.832355	valid_0's binary_logloss: 0.452013
# [453]	valid_0's auc: 0.832361	valid_0's binary_logloss: 0.452002
# [454]	valid_0's auc: 0.832361	valid_0's binary_logloss: 0.451999
# [455]	valid_0's auc: 0.832358	valid_0's binary_logloss: 0.451999
# [456]	valid_0's auc: 0.832349	valid_0's binary_logloss: 0.452004
# [457]	valid_0's auc: 0.832347	valid_0's binary_logloss: 0.452004
# [458]	valid_0's auc: 0.832349	valid_0's binary_logloss: 0.452
# [459]	valid_0's auc: 0.832338	valid_0's binary_logloss: 0.452009
# [460]	valid_0's auc: 0.832335	valid_0's binary_logloss: 0.452006
# [461]	valid_0's auc: 0.832329	valid_0's binary_logloss: 0.452007
# [462]	valid_0's auc: 0.832339	valid_0's binary_logloss: 0.451998
# [463]	valid_0's auc: 0.832343	valid_0's binary_logloss: 0.451994
# [464]	valid_0's auc: 0.832353	valid_0's binary_logloss: 0.451981
# [465]	valid_0's auc: 0.832354	valid_0's binary_logloss: 0.451977
# [466]	valid_0's auc: 0.832347	valid_0's binary_logloss: 0.45198
# [467]	valid_0's auc: 0.832355	valid_0's binary_logloss: 0.45197
# [468]	valid_0's auc: 0.832365	valid_0's binary_logloss: 0.451955
# [469]	valid_0's auc: 0.832362	valid_0's binary_logloss: 0.451956
# [470]	valid_0's auc: 0.832358	valid_0's binary_logloss: 0.451957
# [471]	valid_0's auc: 0.832364	valid_0's binary_logloss: 0.451948
# [472]	valid_0's auc: 0.83236	valid_0's binary_logloss: 0.45195
# [473]	valid_0's auc: 0.832355	valid_0's binary_logloss: 0.451951
# [474]	valid_0's auc: 0.832358	valid_0's binary_logloss: 0.451943
# [475]	valid_0's auc: 0.832356	valid_0's binary_logloss: 0.451946
# [476]	valid_0's auc: 0.832361	valid_0's binary_logloss: 0.451937
# [477]	valid_0's auc: 0.83236	valid_0's binary_logloss: 0.451935
# [478]	valid_0's auc: 0.832363	valid_0's binary_logloss: 0.451925
# [479]	valid_0's auc: 0.832363	valid_0's binary_logloss: 0.451924
# [480]	valid_0's auc: 0.83237	valid_0's binary_logloss: 0.451914
# [481]	valid_0's auc: 0.832378	valid_0's binary_logloss: 0.451902
# [482]	valid_0's auc: 0.832379	valid_0's binary_logloss: 0.451898
# [483]	valid_0's auc: 0.83238	valid_0's binary_logloss: 0.451895
# [484]	valid_0's auc: 0.832379	valid_0's binary_logloss: 0.451896
# [485]	valid_0's auc: 0.832389	valid_0's binary_logloss: 0.451885
# [486]	valid_0's auc: 0.832393	valid_0's binary_logloss: 0.451882
# [487]	valid_0's auc: 0.832393	valid_0's binary_logloss: 0.45188
# [488]	valid_0's auc: 0.832396	valid_0's binary_logloss: 0.451872
# [489]	valid_0's auc: 0.832395	valid_0's binary_logloss: 0.451866
# [490]	valid_0's auc: 0.832394	valid_0's binary_logloss: 0.451866
# [491]	valid_0's auc: 0.832398	valid_0's binary_logloss: 0.451859
# [492]	valid_0's auc: 0.832401	valid_0's binary_logloss: 0.451855
# [493]	valid_0's auc: 0.832405	valid_0's binary_logloss: 0.45185
# [494]	valid_0's auc: 0.832407	valid_0's binary_logloss: 0.451844
# [495]	valid_0's auc: 0.832411	valid_0's binary_logloss: 0.45184
# [496]	valid_0's auc: 0.832411	valid_0's binary_logloss: 0.451837
# [497]	valid_0's auc: 0.832402	valid_0's binary_logloss: 0.451845
# [498]	valid_0's auc: 0.832405	valid_0's binary_logloss: 0.451839
# [499]	valid_0's auc: 0.832403	valid_0's binary_logloss: 0.451837
# [500]	valid_0's auc: 0.832399	valid_0's binary_logloss: 0.451838
# [501]	valid_0's auc: 0.832404	valid_0's binary_logloss: 0.451833
# [502]	valid_0's auc: 0.832407	valid_0's binary_logloss: 0.451829
# [503]	valid_0's auc: 0.832402	valid_0's binary_logloss: 0.451831
# [504]	valid_0's auc: 0.8324	valid_0's binary_logloss: 0.451832
# [505]	valid_0's auc: 0.8324	valid_0's binary_logloss: 0.451831
# [506]	valid_0's auc: 0.832406	valid_0's binary_logloss: 0.451827
# [507]	valid_0's auc: 0.832407	valid_0's binary_logloss: 0.451824
# [508]	valid_0's auc: 0.832408	valid_0's binary_logloss: 0.451821
# [509]	valid_0's auc: 0.832415	valid_0's binary_logloss: 0.451813
# [510]	valid_0's auc: 0.832408	valid_0's binary_logloss: 0.451817
# [511]	valid_0's auc: 0.832408	valid_0's binary_logloss: 0.451815
# [512]	valid_0's auc: 0.832413	valid_0's binary_logloss: 0.45181
# [513]	valid_0's auc: 0.832411	valid_0's binary_logloss: 0.45181
# [514]	valid_0's auc: 0.832413	valid_0's binary_logloss: 0.451803
# [515]	valid_0's auc: 0.832414	valid_0's binary_logloss: 0.4518
# [516]	valid_0's auc: 0.832414	valid_0's binary_logloss: 0.4518
# [517]	valid_0's auc: 0.83241	valid_0's binary_logloss: 0.451803
# [518]	valid_0's auc: 0.832412	valid_0's binary_logloss: 0.451799
# [519]	valid_0's auc: 0.832408	valid_0's binary_logloss: 0.451801
# [520]	valid_0's auc: 0.832407	valid_0's binary_logloss: 0.451802
# [521]	valid_0's auc: 0.832403	valid_0's binary_logloss: 0.451805
# [522]	valid_0's auc: 0.832398	valid_0's binary_logloss: 0.451809
# [523]	valid_0's auc: 0.832398	valid_0's binary_logloss: 0.451808
# [524]	valid_0's auc: 0.832402	valid_0's binary_logloss: 0.451802
# [525]	valid_0's auc: 0.832407	valid_0's binary_logloss: 0.451797
# [526]	valid_0's auc: 0.832409	valid_0's binary_logloss: 0.451794
# [527]	valid_0's auc: 0.832405	valid_0's binary_logloss: 0.451795
# [528]	valid_0's auc: 0.832414	valid_0's binary_logloss: 0.451786
# [529]	valid_0's auc: 0.832415	valid_0's binary_logloss: 0.451784
# [530]	valid_0's auc: 0.83242	valid_0's binary_logloss: 0.45178
# [531]	valid_0's auc: 0.832423	valid_0's binary_logloss: 0.451776
# [532]	valid_0's auc: 0.832426	valid_0's binary_logloss: 0.451772
# [533]	valid_0's auc: 0.832434	valid_0's binary_logloss: 0.451761
# [534]	valid_0's auc: 0.832438	valid_0's binary_logloss: 0.451756
# [535]	valid_0's auc: 0.832442	valid_0's binary_logloss: 0.45175
# [536]	valid_0's auc: 0.832449	valid_0's binary_logloss: 0.45174
# [537]	valid_0's auc: 0.832448	valid_0's binary_logloss: 0.451742
# [538]	valid_0's auc: 0.832446	valid_0's binary_logloss: 0.451741
# [539]	valid_0's auc: 0.83245	valid_0's binary_logloss: 0.451736
# [540]	valid_0's auc: 0.83245	valid_0's binary_logloss: 0.451735
# [541]	valid_0's auc: 0.83245	valid_0's binary_logloss: 0.451734
# [542]	valid_0's auc: 0.832456	valid_0's binary_logloss: 0.451727
# [543]	valid_0's auc: 0.832458	valid_0's binary_logloss: 0.451723
# [544]	valid_0's auc: 0.832456	valid_0's binary_logloss: 0.451725
# [545]	valid_0's auc: 0.832459	valid_0's binary_logloss: 0.451722
# [546]	valid_0's auc: 0.832463	valid_0's binary_logloss: 0.451716
# [547]	valid_0's auc: 0.832458	valid_0's binary_logloss: 0.451721
# [548]	valid_0's auc: 0.832458	valid_0's binary_logloss: 0.451718
# [549]	valid_0's auc: 0.832457	valid_0's binary_logloss: 0.451718
# [550]	valid_0's auc: 0.832453	valid_0's binary_logloss: 0.451721
# [551]	valid_0's auc: 0.832452	valid_0's binary_logloss: 0.451721
# [552]	valid_0's auc: 0.832454	valid_0's binary_logloss: 0.451719
# [553]	valid_0's auc: 0.832458	valid_0's binary_logloss: 0.451713
# [554]	valid_0's auc: 0.832456	valid_0's binary_logloss: 0.451713
# [555]	valid_0's auc: 0.832457	valid_0's binary_logloss: 0.451711
# [556]	valid_0's auc: 0.832456	valid_0's binary_logloss: 0.451711
# [557]	valid_0's auc: 0.832457	valid_0's binary_logloss: 0.45171
# [558]	valid_0's auc: 0.832453	valid_0's binary_logloss: 0.451713
# [559]	valid_0's auc: 0.832458	valid_0's binary_logloss: 0.451709
# [560]	valid_0's auc: 0.832458	valid_0's binary_logloss: 0.451706
# [561]	valid_0's auc: 0.832457	valid_0's binary_logloss: 0.451705
# [562]	valid_0's auc: 0.832462	valid_0's binary_logloss: 0.4517
# [563]	valid_0's auc: 0.832463	valid_0's binary_logloss: 0.451701
# [564]	valid_0's auc: 0.832466	valid_0's binary_logloss: 0.4517
# [565]	valid_0's auc: 0.832464	valid_0's binary_logloss: 0.451699
# [566]	valid_0's auc: 0.83247	valid_0's binary_logloss: 0.451691
# [567]	valid_0's auc: 0.832463	valid_0's binary_logloss: 0.451698
# [568]	valid_0's auc: 0.832466	valid_0's binary_logloss: 0.451695
# [569]	valid_0's auc: 0.832467	valid_0's binary_logloss: 0.451693
# [570]	valid_0's auc: 0.832465	valid_0's binary_logloss: 0.451695
# [571]	valid_0's auc: 0.832458	valid_0's binary_logloss: 0.4517
# [572]	valid_0's auc: 0.832455	valid_0's binary_logloss: 0.451704
# [573]	valid_0's auc: 0.832455	valid_0's binary_logloss: 0.451703
# [574]	valid_0's auc: 0.832454	valid_0's binary_logloss: 0.451701
# [575]	valid_0's auc: 0.832452	valid_0's binary_logloss: 0.451702
# [576]	valid_0's auc: 0.832451	valid_0's binary_logloss: 0.451703
# [577]	valid_0's auc: 0.832453	valid_0's binary_logloss: 0.451702
# [578]	valid_0's auc: 0.832456	valid_0's binary_logloss: 0.451698
# [579]	valid_0's auc: 0.832459	valid_0's binary_logloss: 0.451694
# [580]	valid_0's auc: 0.832464	valid_0's binary_logloss: 0.451688
# [581]	valid_0's auc: 0.832462	valid_0's binary_logloss: 0.45169
# [582]	valid_0's auc: 0.832462	valid_0's binary_logloss: 0.451688
# [583]	valid_0's auc: 0.832467	valid_0's binary_logloss: 0.451683
# [584]	valid_0's auc: 0.832463	valid_0's binary_logloss: 0.451686
# [585]	valid_0's auc: 0.832466	valid_0's binary_logloss: 0.451684
# [586]	valid_0's auc: 0.832466	valid_0's binary_logloss: 0.451684
# [587]	valid_0's auc: 0.832466	valid_0's binary_logloss: 0.451683
# [588]	valid_0's auc: 0.832472	valid_0's binary_logloss: 0.451676
# [589]	valid_0's auc: 0.832476	valid_0's binary_logloss: 0.451671
# [590]	valid_0's auc: 0.832474	valid_0's binary_logloss: 0.451673
# [591]	valid_0's auc: 0.832476	valid_0's binary_logloss: 0.451671
# [592]	valid_0's auc: 0.832476	valid_0's binary_logloss: 0.451671
# [593]	valid_0's auc: 0.832476	valid_0's binary_logloss: 0.45167
# [594]	valid_0's auc: 0.832477	valid_0's binary_logloss: 0.451667
# [595]	valid_0's auc: 0.832478	valid_0's binary_logloss: 0.451665
# [596]	valid_0's auc: 0.832476	valid_0's binary_logloss: 0.451666
# [597]	valid_0's auc: 0.832476	valid_0's binary_logloss: 0.451666
# [598]	valid_0's auc: 0.832472	valid_0's binary_logloss: 0.451669
# [599]	valid_0's auc: 0.832475	valid_0's binary_logloss: 0.451666
# [600]	valid_0's auc: 0.832477	valid_0's binary_logloss: 0.451664
# [601]	valid_0's auc: 0.832477	valid_0's binary_logloss: 0.451663
# [602]	valid_0's auc: 0.832478	valid_0's binary_logloss: 0.451662
# [603]	valid_0's auc: 0.832477	valid_0's binary_logloss: 0.451662
# [604]	valid_0's auc: 0.832479	valid_0's binary_logloss: 0.451658
# [605]	valid_0's auc: 0.83248	valid_0's binary_logloss: 0.451656
# [606]	valid_0's auc: 0.83248	valid_0's binary_logloss: 0.451656
# [607]	valid_0's auc: 0.83248	valid_0's binary_logloss: 0.451656
# [608]	valid_0's auc: 0.832482	valid_0's binary_logloss: 0.451653
# [609]	valid_0's auc: 0.83248	valid_0's binary_logloss: 0.451652
# [610]	valid_0's auc: 0.832475	valid_0's binary_logloss: 0.451656
# [611]	valid_0's auc: 0.832475	valid_0's binary_logloss: 0.451657
# [612]	valid_0's auc: 0.832478	valid_0's binary_logloss: 0.451655
# [613]	valid_0's auc: 0.83248	valid_0's binary_logloss: 0.451653
# [614]	valid_0's auc: 0.832481	valid_0's binary_logloss: 0.451651
# [615]	valid_0's auc: 0.832482	valid_0's binary_logloss: 0.451649
# [616]	valid_0's auc: 0.832482	valid_0's binary_logloss: 0.451649
# [617]	valid_0's auc: 0.832484	valid_0's binary_logloss: 0.451647
# [618]	valid_0's auc: 0.832486	valid_0's binary_logloss: 0.451644
# [619]	valid_0's auc: 0.832486	valid_0's binary_logloss: 0.451644
# [620]	valid_0's auc: 0.832484	valid_0's binary_logloss: 0.451646
# [621]	valid_0's auc: 0.83248	valid_0's binary_logloss: 0.451648
# [622]	valid_0's auc: 0.832482	valid_0's binary_logloss: 0.451647
# [623]	valid_0's auc: 0.832483	valid_0's binary_logloss: 0.451645
# [624]	valid_0's auc: 0.832482	valid_0's binary_logloss: 0.451645
# [625]	valid_0's auc: 0.832484	valid_0's binary_logloss: 0.451644
# [626]	valid_0's auc: 0.832484	valid_0's binary_logloss: 0.451642
# [627]	valid_0's auc: 0.832485	valid_0's binary_logloss: 0.45164
# [628]	valid_0's auc: 0.832485	valid_0's binary_logloss: 0.45164
# [629]	valid_0's auc: 0.832481	valid_0's binary_logloss: 0.451643
# [630]	valid_0's auc: 0.832481	valid_0's binary_logloss: 0.451644
# [631]	valid_0's auc: 0.832481	valid_0's binary_logloss: 0.451644
# [632]	valid_0's auc: 0.832487	valid_0's binary_logloss: 0.451638
# [633]	valid_0's auc: 0.832488	valid_0's binary_logloss: 0.451637
# [634]	valid_0's auc: 0.832492	valid_0's binary_logloss: 0.451632
# [635]	valid_0's auc: 0.832492	valid_0's binary_logloss: 0.451632
# [636]	valid_0's auc: 0.832491	valid_0's binary_logloss: 0.451632
# [637]	valid_0's auc: 0.832491	valid_0's binary_logloss: 0.451632
# [638]	valid_0's auc: 0.832491	valid_0's binary_logloss: 0.451631
# [639]	valid_0's auc: 0.832489	valid_0's binary_logloss: 0.451634
# [640]	valid_0's auc: 0.832487	valid_0's binary_logloss: 0.451635
# [641]	valid_0's auc: 0.83249	valid_0's binary_logloss: 0.451632
# [642]	valid_0's auc: 0.83249	valid_0's binary_logloss: 0.451631
# [643]	valid_0's auc: 0.832493	valid_0's binary_logloss: 0.451627
# [644]	valid_0's auc: 0.83249	valid_0's binary_logloss: 0.45163
# [645]	valid_0's auc: 0.832489	valid_0's binary_logloss: 0.45163
# [646]	valid_0's auc: 0.832487	valid_0's binary_logloss: 0.451632
# [647]	valid_0's auc: 0.832485	valid_0's binary_logloss: 0.451633
# [648]	valid_0's auc: 0.832489	valid_0's binary_logloss: 0.451629
# [649]	valid_0's auc: 0.832492	valid_0's binary_logloss: 0.451625
# [650]	valid_0's auc: 0.832494	valid_0's binary_logloss: 0.451623
# [651]	valid_0's auc: 0.832489	valid_0's binary_logloss: 0.451628
# [652]	valid_0's auc: 0.832489	valid_0's binary_logloss: 0.451628
# [653]	valid_0's auc: 0.83249	valid_0's binary_logloss: 0.451627
# [654]	valid_0's auc: 0.83249	valid_0's binary_logloss: 0.451626
# [655]	valid_0's auc: 0.83249	valid_0's binary_logloss: 0.451626
# [656]	valid_0's auc: 0.832491	valid_0's binary_logloss: 0.451624
# [657]	valid_0's auc: 0.832492	valid_0's binary_logloss: 0.451624
# [658]	valid_0's auc: 0.832495	valid_0's binary_logloss: 0.45162
# [659]	valid_0's auc: 0.832496	valid_0's binary_logloss: 0.451619
# [660]	valid_0's auc: 0.832496	valid_0's binary_logloss: 0.451619
# [661]	valid_0's auc: 0.832499	valid_0's binary_logloss: 0.451616
# [662]	valid_0's auc: 0.832496	valid_0's binary_logloss: 0.451617
# [663]	valid_0's auc: 0.832498	valid_0's binary_logloss: 0.451616
# [664]	valid_0's auc: 0.832499	valid_0's binary_logloss: 0.451615
# [665]	valid_0's auc: 0.832501	valid_0's binary_logloss: 0.451612
# [666]	valid_0's auc: 0.832499	valid_0's binary_logloss: 0.451615
# [667]	valid_0's auc: 0.832501	valid_0's binary_logloss: 0.451613
# [668]	valid_0's auc: 0.832501	valid_0's binary_logloss: 0.451612
# [669]	valid_0's auc: 0.8325	valid_0's binary_logloss: 0.451614
# [670]	valid_0's auc: 0.8325	valid_0's binary_logloss: 0.451613
# [671]	valid_0's auc: 0.832502	valid_0's binary_logloss: 0.451612
# [672]	valid_0's auc: 0.832503	valid_0's binary_logloss: 0.451613
# [673]	valid_0's auc: 0.8325	valid_0's binary_logloss: 0.451615
# [674]	valid_0's auc: 0.832501	valid_0's binary_logloss: 0.451614
# [675]	valid_0's auc: 0.832501	valid_0's binary_logloss: 0.451612
# [676]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.451607
# [677]	valid_0's auc: 0.832506	valid_0's binary_logloss: 0.451607
# [678]	valid_0's auc: 0.832506	valid_0's binary_logloss: 0.451606
# [679]	valid_0's auc: 0.832506	valid_0's binary_logloss: 0.451606
# [680]	valid_0's auc: 0.832503	valid_0's binary_logloss: 0.451609
# [681]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.451608
# [682]	valid_0's auc: 0.832507	valid_0's binary_logloss: 0.451605
# [683]	valid_0's auc: 0.832507	valid_0's binary_logloss: 0.451603
# [684]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.451605
# [685]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.451604
# [686]	valid_0's auc: 0.832506	valid_0's binary_logloss: 0.451604
# [687]	valid_0's auc: 0.832507	valid_0's binary_logloss: 0.451602
# [688]	valid_0's auc: 0.832507	valid_0's binary_logloss: 0.451602
# [689]	valid_0's auc: 0.832508	valid_0's binary_logloss: 0.4516
# [690]	valid_0's auc: 0.832509	valid_0's binary_logloss: 0.451598
# [691]	valid_0's auc: 0.832506	valid_0's binary_logloss: 0.4516
# [692]	valid_0's auc: 0.832503	valid_0's binary_logloss: 0.451603
# [693]	valid_0's auc: 0.8325	valid_0's binary_logloss: 0.451606
# [694]	valid_0's auc: 0.832499	valid_0's binary_logloss: 0.451607
# [695]	valid_0's auc: 0.832503	valid_0's binary_logloss: 0.451603
# [696]	valid_0's auc: 0.832504	valid_0's binary_logloss: 0.451602
# [697]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.4516
# [698]	valid_0's auc: 0.832504	valid_0's binary_logloss: 0.451602
# [699]	valid_0's auc: 0.832504	valid_0's binary_logloss: 0.451602
# [700]	valid_0's auc: 0.832504	valid_0's binary_logloss: 0.451602
# [701]	valid_0's auc: 0.832504	valid_0's binary_logloss: 0.451601
# [702]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.4516
# [703]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.451599
# [704]	valid_0's auc: 0.832507	valid_0's binary_logloss: 0.451597
# [705]	valid_0's auc: 0.832505	valid_0's binary_logloss: 0.451598
# [706]	valid_0's auc: 0.832506	valid_0's binary_logloss: 0.451597
# [707]	valid_0's auc: 0.832504	valid_0's binary_logloss: 0.451599
# [708]	valid_0's auc: 0.832504	valid_0's binary_logloss: 0.451598
# [709]	valid_0's auc: 0.832507	valid_0's binary_logloss: 0.451596
# [710]	valid_0's auc: 0.832508	valid_0's binary_logloss: 0.451595
# [711]	valid_0's auc: 0.832509	valid_0's binary_logloss: 0.451595
# [712]	valid_0's auc: 0.832509	valid_0's binary_logloss: 0.451594
# [713]	valid_0's auc: 0.832509	valid_0's binary_logloss: 0.451593
# [714]	valid_0's auc: 0.83251	valid_0's binary_logloss: 0.451594
# [715]	valid_0's auc: 0.83251	valid_0's binary_logloss: 0.451593
# [716]	valid_0's auc: 0.83251	valid_0's binary_logloss: 0.451592
# [717]	valid_0's auc: 0.83251	valid_0's binary_logloss: 0.451593
# [718]	valid_0's auc: 0.83251	valid_0's binary_logloss: 0.451593
# [719]	valid_0's auc: 0.832512	valid_0's binary_logloss: 0.451592
# [720]	valid_0's auc: 0.832512	valid_0's binary_logloss: 0.451591
# [721]	valid_0's auc: 0.832512	valid_0's binary_logloss: 0.451591
# [722]	valid_0's auc: 0.832513	valid_0's binary_logloss: 0.451588
# [723]	valid_0's auc: 0.832513	valid_0's binary_logloss: 0.451588
# [724]	valid_0's auc: 0.832514	valid_0's binary_logloss: 0.451587
# [725]	valid_0's auc: 0.832514	valid_0's binary_logloss: 0.451587
# [726]	valid_0's auc: 0.832513	valid_0's binary_logloss: 0.451588
# [727]	valid_0's auc: 0.832513	valid_0's binary_logloss: 0.451588
# [728]	valid_0's auc: 0.832516	valid_0's binary_logloss: 0.451586
# [729]	valid_0's auc: 0.832516	valid_0's binary_logloss: 0.451585
# [730]	valid_0's auc: 0.832517	valid_0's binary_logloss: 0.451585
# [731]	valid_0's auc: 0.832518	valid_0's binary_logloss: 0.451583
# [732]	valid_0's auc: 0.832517	valid_0's binary_logloss: 0.451583
# [733]	valid_0's auc: 0.832518	valid_0's binary_logloss: 0.451583
# [734]	valid_0's auc: 0.832519	valid_0's binary_logloss: 0.451581
# [735]	valid_0's auc: 0.832515	valid_0's binary_logloss: 0.451585
# [736]	valid_0's auc: 0.832518	valid_0's binary_logloss: 0.451582
# [737]	valid_0's auc: 0.832519	valid_0's binary_logloss: 0.451582
# [738]	valid_0's auc: 0.832522	valid_0's binary_logloss: 0.451577
# [739]	valid_0's auc: 0.832521	valid_0's binary_logloss: 0.451578
# [740]	valid_0's auc: 0.832522	valid_0's binary_logloss: 0.451577
# [741]	valid_0's auc: 0.832519	valid_0's binary_logloss: 0.45158
# [742]	valid_0's auc: 0.832517	valid_0's binary_logloss: 0.451583
# ...
# [999]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451532
# [1000]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451531
# [1001]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451531
# [1002]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451532
# [1003]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451532
# [1004]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451532
# [1005]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451533
# [1006]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451533
# [1007]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451534
# [1008]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451534
# [1009]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451533
# [1010]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451533
# [1011]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451533
# [1012]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451535
# [1013]	valid_0's auc: 0.832559	valid_0's binary_logloss: 0.451536
# [1014]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451534
# [1015]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451535
# [1016]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451536
# [1017]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451534
# [1018]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451535
# [1019]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451534
# [1020]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451535
# [1021]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451533
# [1022]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451535
# [1023]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451534
# [1024]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451533
# [1025]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1026]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451532
# [1027]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451533
# [1028]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1029]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451532
# [1030]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451531
# [1031]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451533
# [1032]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451536
# [1033]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451537
# [1034]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451537
# [1035]	valid_0's auc: 0.832559	valid_0's binary_logloss: 0.451539
# [1036]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451538
# [1037]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451537
# [1038]	valid_0's auc: 0.832557	valid_0's binary_logloss: 0.45154
# [1039]	valid_0's auc: 0.832558	valid_0's binary_logloss: 0.45154
# [1040]	valid_0's auc: 0.832558	valid_0's binary_logloss: 0.451539
# [1041]	valid_0's auc: 0.832558	valid_0's binary_logloss: 0.45154
# [1042]	valid_0's auc: 0.832558	valid_0's binary_logloss: 0.451539
# [1043]	valid_0's auc: 0.832558	valid_0's binary_logloss: 0.451539
# [1044]	valid_0's auc: 0.832559	valid_0's binary_logloss: 0.451538
# [1045]	valid_0's auc: 0.832559	valid_0's binary_logloss: 0.451538
# [1046]	valid_0's auc: 0.832559	valid_0's binary_logloss: 0.451538
# [1047]	valid_0's auc: 0.832559	valid_0's binary_logloss: 0.451538
# [1048]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451538
# [1049]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451536
# [1050]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451536
# [1051]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451536
# [1052]	valid_0's auc: 0.83256	valid_0's binary_logloss: 0.451536
# [1053]	valid_0's auc: 0.832561	valid_0's binary_logloss: 0.451536
# [1054]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1055]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1056]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1057]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451535
# [1058]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1059]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451535
# [1060]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451535
# [1061]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451535
# [1062]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1063]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451535
# [1064]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451534
# [1065]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451534
# [1066]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451533
# [1067]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451533
# [1068]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1069]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451532
# [1070]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451531
# [1071]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451531
# [1072]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451532
# [1073]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451532
# [1074]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451532
# [1075]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451531
# [1076]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1077]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451531
# [1078]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451532
# [1079]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1080]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451532
# [1081]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451531
# [1082]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451533
# [1083]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451533
# [1084]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1085]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451535
# [1086]	valid_0's auc: 0.832562	valid_0's binary_logloss: 0.451537
# [1087]	valid_0's auc: 0.832563	valid_0's binary_logloss: 0.451536
# [1088]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451534
# [1089]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451534
# [1090]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451534
# [1091]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1092]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1093]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1094]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1095]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1096]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451534
# [1097]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1098]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1099]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451532
# [1100]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451531
# [1101]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451532
# [1102]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1103]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451531
# [1104]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451532
# [1105]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451532
# [1106]	valid_0's auc: 0.832564	valid_0's binary_logloss: 0.451533
# [1107]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1108]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451533
# [1109]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1110]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1111]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1112]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1113]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1114]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1115]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1116]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451529
# [1117]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1118]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1119]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451528
# [1120]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1121]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1122]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1123]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1124]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1125]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.45153
# [1126]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.45153
# [1127]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451532
# [1128]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1129]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451528
# [1130]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1131]	valid_0's auc: 0.832571	valid_0's binary_logloss: 0.451527
# [1132]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451528
# [1133]	valid_0's auc: 0.832572	valid_0's binary_logloss: 0.451526
# [1134]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451528
# [1135]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1136]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1137]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.45153
# [1138]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1139]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1140]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1141]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1142]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1143]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1144]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1145]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1146]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1147]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1148]	valid_0's auc: 0.832571	valid_0's binary_logloss: 0.451528
# [1149]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1150]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1151]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1152]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1153]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451531
# [1154]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.45153
# [1155]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451529
# [1156]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1157]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1158]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1159]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451529
# [1160]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1161]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1162]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451529
# [1163]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1164]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451531
# [1165]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1166]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451531
# [1167]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1168]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.45153
# [1169]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1170]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1171]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1172]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.45153
# [1173]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1174]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1175]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1176]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451528
# [1177]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1178]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1179]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1180]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1181]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1182]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.45153
# [1183]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1184]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1185]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1186]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451528
# [1187]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1188]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1189]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1190]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1191]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1192]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451529
# [1193]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1194]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1195]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.45153
# [1196]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451531
# [1197]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.45153
# [1198]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.45153
# [1199]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.45153
# [1200]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.451529
# [1201]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.451528
# [1202]	valid_0's auc: 0.83257	valid_0's binary_logloss: 0.45153
# [1203]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451532
# [1204]	valid_0's auc: 0.832569	valid_0's binary_logloss: 0.45153
# [1205]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451532
# [1206]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451532
# [1207]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1208]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451532
# [1209]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451532
# [1210]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451533
# [1211]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1212]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1213]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1214]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1215]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451534
# [1216]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451534
# [1217]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451534
# [1218]	valid_0's auc: 0.832565	valid_0's binary_logloss: 0.451534
# [1219]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451534
# [1220]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1221]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451534
# [1222]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451534
# [1223]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451534
# [1224]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451533
# [1225]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451532
# [1226]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451532
# [1227]	valid_0's auc: 0.832568	valid_0's binary_logloss: 0.451532
# [1228]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1229]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451534
# [1230]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451533
# [1231]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.451533
# [1232]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451532
# [1233]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.451532
# Early stopping, best iteration is:
# [1133]	valid_0's auc: 0.832572	valid_0's binary_logloss: 0.451526
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.7,
#         importance_type='split', learning_rate=0.3, max_depth=1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=5000, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=0.7, subsample_for_bin=200000, subsample_freq=0,
#         verbose=100)

# %%
test = pd.read_csv('../data/cat_in_the_dat_test.csv', index_col='id')
categ_cols = train.select_dtypes(include=['object']).columns.to_list()
for col in categ_cols:
    test[col] = test[col].map(train.groupby(col)['target'].mean())
    
test.head()
# Out:
#         bin_0  bin_1  bin_2     bin_3     bin_4     nom_0     nom_1     nom_2  \
# id
# 300000      0      0      1  0.302537  0.290107  0.241790  0.360978  0.319017
# 300001      0      0      0  0.302537  0.333773  0.351052  0.338932  0.293085
# 300002      1      0      1  0.309384  0.290107  0.241790  0.338932  0.245139
# 300003      0      0      1  0.302537  0.290107  0.351052  0.310627  0.335367
# 300004      0      1      1  0.309384  0.333773  0.351052  0.290054  0.245139
#
#            nom_3     nom_4  ...     nom_8     nom_9  ord_0     ord_1  \
# id                          ...
# 300000  0.242813  0.304164  ...  0.348315  0.181818      2  0.242055
# 300001  0.339793  0.304164  ...  0.222707  0.288889      1  0.355078
# 300002  0.311724  0.304164  ...  0.186667  0.090909      2  0.317175
# 300003  0.311724  0.304164  ...  0.360656  0.320000      1  0.278533
# 300004  0.311724  0.304164  ...  0.375000  0.294118      3  0.403885
#
#            ord_2     ord_3     ord_4     ord_5       day     month
# id
# 300000  0.288796  0.342476  0.324947  0.300588  0.273121  0.364099
# 300001  0.403126  0.379277  0.186877  0.244795  0.340292  0.317053
# 300002  0.225214  0.206599  0.236891  0.417726  0.336113  0.353634
# 300003  0.403126  0.220460  0.336264  0.365151  0.322048  0.280936
# 300004  0.403126  0.379277  0.409481  0.389864  0.252139  0.364099
#
# [5 rows x 23 columns]

# %%
y_preds = LGBM.predict_proba(test)[:,1] 
y_preds
# Out:
# array([0.20212615, 0.65805746, 0.02674929, ..., 0.43007302, 0.56577997,
#        0.2195374 ])

# %%
test = pd.read_csv('../data/cat_in_the_dat_test.csv')
test["target"] = y_preds
submission = test[["id", "target"]]
submission.head()
# Out:
#        id    target
# 0  300000  0.202126
# 1  300001  0.658057
# 2  300002  0.026749
# 3  300003  0.580573
# 4  300004  0.838201

# %%
submission.to_csv('../data/Submissions/cat_in_the_dat_sub1.csv', index=False)
